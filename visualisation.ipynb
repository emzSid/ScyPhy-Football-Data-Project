# %%
import pandas as pd
from SP_project import *

# %%
players = pd.read_csv('female_players_22.csv')
add_rankingtype(players)
clean_data_to_purpose(players)

# %% [markdown]
# <h3>The women's euro is approaching!</h3>

# %% [markdown]
# <p>Let's get to know the different teams and compare them. <br><br>
# First, which nation has the most world class players and which nation is composoed of rather moderate players? </p>

# %%
player_type_dis(players,'none')

# %% [markdown]
# <p>You want to zoom into three specific nations? <br>No problem!<br> Just select them in the function as second argument:</p>

# %%
player_type_dis(players, ['England', 'Portugal', 'Norway'])

# %% [markdown]
# <p>For sure! The most interesting fact in a match is the lineup and formation of the teams. <br> You ever wondered if a team is actually playing with the formation which suits the players best? <br> Now you'll now!<br> <h5>The following function calculates the best formation for the specified team by maximizing its overall rating and returns a table with the best lineup.</h5> <br> Let's try with Germany: </p>

# %%
get_best_formation(players, 'Germany')
# Out:
# One of the best formations for Germany is the 1-4-2-3-1.
# With the following lineup its overall rating is then 84.64.
#              Overall Rating            Position
# Name
# L. Benkarth              84          Goalkeeper
# G. Gwinn                 84           Rightback
# L. Oberdorf              84          Centerback
# K. Hendrich              82          Centerback
# L. Maier                 82            Leftback
# D. Marozsán              90  Central Midfielder
# S. Däbritz               87  Central Midfielder
# S. Huth                  84    Right Midfielder
# L. Magull                84  Central Midfielder
# A. Popp                  88     Left Midfielder
# L. Dallmann              82             Forward

# %% [markdown]
# A player in the list catched your attention and you want to know more?

# %%
player_info(players, 'S. Däbritz')

# %% [markdown]
# <p> In a tournament the teams will probably need to shoot some penalties. But which players should shoot? <br> As an example: the french coach can trust the following players: </p>

# %%
get_top5(players,'France', 'mentality_penalties')

# %% [markdown]
# <p> You want to know which young talents you should keep an eye on during the tournament? <br> Here they are::</p>

# %%
youngsters_to_watch_out(players)

# %% [markdown]
# Finally, let's dive deeper into the player ratings. <br> Here are three correlations compared for defenders and attackers:

# %%
physic_overall_corr(players)

# %% [markdown]
# <p> Interesting!<br> Hence, being good at passing and having an excellent ball control is crucial for attackers. In contrast, defenders also can get a very high overall rating without these skills. On the right side we can see that the defenders tend to have a better physic. However, a high overall rating does not mean that you have a better physic as well.
